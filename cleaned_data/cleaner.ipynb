# %%
import pandas as pd

# %%
df=pd.read_csv('./BGC_data/bcg_data_latest1.csv')

# %%
df.drop(columns=['Unnamed: 0.2','first'],inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.to_csv('./BGC_data/cleaned.csv')
